# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\hp\Downloads\apple_quality.csv')
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# 2                           2.621636473     bad
# 3                           0.790723217    good
# 4                           0.501984036    good
# ...                                 ...     ...
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN
#
# [4001 rows x 9 columns]

# %%
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
df.tail()
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN

# %%
df.dtypes
# Out:
# A_id           float64
# Size           float64
# Weight         float64
# Sweetness      float64
# Crunchiness    float64
# Juiciness      float64
# Ripeness       float64
# Acidity         object
# Quality         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# A_id           1
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
cat=df.select_dtypes(include=[object]).columns
num=df.select_dtypes(exclude=[object]).columns
print('CAT:',cat)
print('Num:',num)
# Out:
# CAT: Index(['Acidity', 'Quality'], dtype='object')
# Num: Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness'],
#       dtype='object')

# %%
df=df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# A_id           0
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# Quality        0
# dtype: int64

# %%
for i in cat:
    a=df[i].unique()
    print(i,a)
# Out:
# Acidity ['-0.491590483' '-0.722809367' '2.621636473' ... '-1.334611391'
#  '-2.229719806' '1.599796456']
# Quality ['good' 'bad']

# %%
for i in cat:
    a=df[i].nunique()
    print(i,a)
# Out:
# Acidity 4000
# Quality 2

# %%
plt.figure(figsize=(10,15))
for i,column in enumerate(cat):
    plt.subplot(4,2,i+1)

    ax=sns.countplot(data=df,x=column)
    ax.bar_label(ax.containers[0])
plt.show()

# %%
for i in num:
    d_count=round(df[i].count(),2)
    d_max=round(df[i].max(),2)
    d_min=round(df[i].min(),2)
    d_mean=round(df[i].mean(),2)
    d_median=round(df[i].median(),2)
    d_std=round(df[i].std(),2)

    print(i,'count:',d_count)
    print(i,'max:',d_max)
    print(i,'min:',d_min)
    print(i,'mean:',d_mean)
    print(i,'median:',d_median)
    print(i,'std:',d_std)
    print('------------------------------------')
# Out:
# A_id count: 4000
# A_id max: 3999.0
# A_id min: 0.0
# A_id mean: 1999.5
# A_id median: 1999.5
# A_id std: 1154.84
# ------------------------------------
# Size count: 4000
# Size max: 6.41
# Size min: -7.15
# Size mean: -0.5
# Size median: -0.51
# Size std: 1.93
# ------------------------------------
# Weight count: 4000
# Weight max: 5.79
# Weight min: -7.15
# Weight mean: -0.99
# Weight median: -0.98
# Weight std: 1.6
# ------------------------------------
# Sweetness count: 4000
# Sweetness max: 6.37
# Sweetness min: -6.89
# Sweetness mean: -0.47
# Sweetness median: -0.5
# Sweetness std: 1.94
# ------------------------------------
# Crunchiness count: 4000
# Crunchiness max: 7.62
# Crunchiness min: -6.06
# Crunchiness mean: 0.99
# Crunchiness median: 1.0
# Crunchiness std: 1.4
# ------------------------------------
# Juiciness count: 4000
# Juiciness max: 7.36
# Juiciness min: -5.96
# Juiciness mean: 0.51
# Juiciness median: 0.53
# Juiciness std: 1.93
# ------------------------------------
# Ripeness count: 4000
# Ripeness max: 7.24
# Ripeness min: -5.86
# Ripeness mean: 0.5
# Ripeness median: 0.5
# Ripeness std: 1.87
# ------------------------------------

# %%
for i in num:
    q1=np.quantile(df[i],0.25)
    q2=np.quantile(df[i],0.50)
    q3=np.quantile(df[i],0.75)
    print(i,'q1:',q1)
    print(i,'q2:',q2)
    print(i,'q3:',3)
    print('------------')
# Out:
# A_id q1: 999.75
# A_id q2: 1999.5
# A_id q3: 3
# ------------
# Size q1: -1.816764527
# Size q2: -0.5137025125000001
# Size q3: 3
# ------------
# Weight q1: -2.01177029275
# Weight q2: -0.9847364865
# Weight q3: 3
# ------------
# Sweetness q1: -1.7384250625
# Sweetness q2: -0.5047584635
# Sweetness q3: 3
# ------------
# Crunchiness q1: 0.06276439525000001
# Crunchiness q2: 0.9982494390000001
# Crunchiness q3: 3
# ------------
# Juiciness q1: -0.80128581525
# Juiciness q2: 0.5342186584999999
# Juiciness q3: 3
# ------------
# Ripeness q1: -0.7716768665
# Ripeness q2: 0.5034447135
# Ripeness q3: 3
# ------------

# %%
df.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %%
plt.figure(figsize=(10,15))
for i,column in enumerate(num[1:]):
    plt.subplot(4,2,i+1)
    plt.title(column)
    plt.hist(df[column],bins=40)
plt.show()

# %%
for i in num[1:]:
    #plt.subplot(3,2,i+1)
    sns.distplot(df[i])
   # plt.subplot(3,2,i+1)
    plt.show()

# %%
plt.figure(figsize=(10,15))
for i,column in enumerate(num[1:]):
    plt.subplot(3,2,i+1)
    plt.title(column)
    plt.boxplot(df[column])
plt.show()

# %%
q1=np.quantile(df['Size'],0.25)
q2=np.quantile(df['Size'],0.50)
q3=np.quantile(df['Size'],0.75)

iqr=q3-q1

ub1=q3+(1.5*iqr)
lb1=q1-(1.5*iqr)

con1=df['Size']>ub1
con2=df['Size']<lb1
outlier=df[con1|con2]
len(outlier)
# Out:
# 22

# %%
q1=np.quantile(df['Weight'],0.25)
q2=np.quantile(df['Weight'],0.50)
q3=np.quantile(df['Weight'],0.75)

iqr=q3-q1

ub2=q3+(1.5*iqr)
lb2=q1-(1.5*iqr)

con1=df['Weight']>ub2
con2=df['Weight']<lb2

outlier=df[con1|con2]
len(outlier)
# Out:
# 54

# %%
q1=np.quantile(df['Sweetness'],0.25)
q2=np.quantile(df['Sweetness'],0.50)
q3=np.quantile(df['Sweetness'],0.75)

iqr=q3-q1

ub3=q3+(1.5*iqr)
lb3=q1-(1.5*iqr)

con1=df['Sweetness']>ub3
con2=df['Sweetness']<lb3

outlier=df[con1|con2]
len(outlier)
# Out:
# 32

# %%
q1=np.quantile(df['Crunchiness'],0.25)
q2=np.quantile(df['Crunchiness'],0.50)
q3=np.quantile(df['Crunchiness'],0.75)

iqr=q3-q1

ub4=q3+(1.5*iqr)
lb4=q1-(1.5*iqr)

con1=df['Crunchiness']>ub4
con2=df['Crunchiness']<lb4

outlier=df[con1|con2]
len(outlier)
# Out:
# 47

# %%
q1=np.quantile(df['Juiciness'],0.25)
q2=np.quantile(df['Juiciness'],0.50)
q3=np.quantile(df['Juiciness'],0.75)

iqr=q3-q1

ub5=q3+(1.5*iqr)
lb5=q1-(1.5*iqr)

con1=df['Juiciness']>ub5
con2=df['Juiciness']<lb5

outlier=df[con1|con2]
len(outlier)
# Out:
# 32

# %%
q1=np.quantile(df['Ripeness'],0.25)
q2=np.quantile(df['Ripeness'],0.50)
q3=np.quantile(df['Ripeness'],0.75)

iqr=q3-q1

ub6=q3+(1.5*iqr)
lb6=q1-(1.5*iqr)

con1=df['Ripeness']>ub6
con2=df['Ripeness']<lb6

outlier=df[con1|con2]
len(outlier)
# Out:
# 24

# %%
import pandas as pd
from scipy.stats import zscore

# Sample dataset


# Calculate Z-scores
z_scores = zscore(df[num])

# Set a Z-score threshold (e.g., 2)
z_score_threshold = 2

# Identify and remove outliers
df_no_outliers = df[(np.abs(z_scores) < z_score_threshold)]

# Display the results
print("Original Data:\n", df[num])
print("\nData without outliers based on Z-score:\n", df_no_outliers[num])
# Out:
# Original Data:
#          A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
# [4000 rows x 7 columns]
#
# Data without outliers based on Z-score:
#          A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness
# 0        0.0 -3.970049 -2.512336        NaN    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257        NaN     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970       NaN
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709       NaN
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
# [4000 rows x 7 columns]

# %%
plt.figure(figsize=(10,15))
for i,column in enumerate(num[1:]):
    plt.subplot(3,2,i+1)
    plt.title(column)
    plt.boxplot(df[column])
plt.show()

# %%
df['Size']=np.clip(df['Size'],lb1,ub1)

# %%
df['Weight']=np.clip(df['Weight'],lb2,ub2)

# %%
df['Sweetness']=np.clip(df['Sweetness'],lb3,ub3)

# %%
df['Crunchiness']=np.clip(df['Crunchiness'],lb4,ub4)

# %%
df['Juiciness']=np.clip(df['Juiciness'],lb5,ub5)

# %%
df['Ripeness']=np.clip(df['Ripeness'],lb6,ub6)

# %%
plt.figure(figsize=(10,15))
for i,column in enumerate(num[1:]):
    plt.subplot(3,2,i+1)
    plt.title(column)
    plt.boxplot(df[column])
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the total number of plots (rows * columns)
total_plots = 7* 3

# Create a figure and axes for the subplots
fig, axes = plt.subplots(7, 3, figsize=(15, 30))  # 5 rows, 4 columns - Adjust the figsize as needed

# Your existing code with minor modifications
plot_counter = 0  # Initialize a counter for subplot positions

for i in num[1:]:
    for j in num[1:]:
        if i != j and plot_counter < total_plots:  # Check if plot_counter exceeds total_plots
            ax = axes[plot_counter // 3, plot_counter % 3]  # Get the current subplot
            ax.scatter(df[i], df[j])
            ax.set_title(f'Columns: {i} vs {j}')
            plot_counter += 1  # Increment the plot counter

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

# %%
corr=df.corr(numeric_only=True)
corr
# Out:
#                  A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# A_id         1.000000 -0.028722 -0.005954  -0.001819    -0.013516   0.005579
# Size        -0.028722  1.000000 -0.166974  -0.324412     0.169820  -0.019437
# Weight      -0.005954 -0.166974  1.000000  -0.152070    -0.095068  -0.092135
# Sweetness   -0.001819 -0.324412 -0.152070   1.000000    -0.033874   0.095436
# Crunchiness -0.013516  0.169820 -0.095068  -0.033874     1.000000  -0.257884
# Juiciness    0.005579 -0.019437 -0.092135   0.095436    -0.257884   1.000000
# Ripeness     0.000252 -0.135910 -0.243678  -0.273578    -0.200391  -0.098975
#
#              Ripeness
# A_id         0.000252
# Size        -0.135910
# Weight      -0.243678
# Sweetness   -0.273578
# Crunchiness -0.200391
# Juiciness   -0.098975
# Ripeness     1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   4.612442    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# 0     -0.491590483    good
# 1     -0.722809367    good
# 2      2.621636473     bad
# 3      0.790723217    good
# 4      0.501984036    good
# ...            ...     ...
# 3995   0.137784369     bad
# 3996   1.854235285    good
# 3997  -1.334611391     bad
# 3998  -2.229719806    good
# 3999   1.599796456    good
#
# [4000 rows x 9 columns]

# %%
num
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness'],
#       dtype='object')

# %%
for i in num:
    a=df[i].skew()
    print(i,a)
# Out:
# A_id 0.0
# Size 0.0012754534194467813
# Weight -0.026394534982838332
# Sweetness 0.06493221067593026
# Crunchiness -0.03304597711467635
# Juiciness -0.10378638775315034
# Ripeness -0.011571346209078771

# %%
cat
# Out:
# Index(['Acidity', 'Quality'], dtype='object')

# %%
# from sklearn.preprocessing import LabelEncoder
# le=LabelEncoder()
# df['Acidity']=le.fit_transform(df['Acidity'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Quality']=le.fit_transform(df['Quality'])

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   4.612442    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity  Quality
# 0     -0.491590483        1
# 1     -0.722809367        1
# 2      2.621636473        0
# 3      0.790723217        1
# 4      0.501984036        1
# ...            ...      ...
# 3995   0.137784369        0
# 3996   1.854235285        1
# 3997  -1.334611391        0
# 3998  -2.229719806        1
# 3999   1.599796456        1
#
# [4000 rows x 9 columns]

# %%
df['Acidity'] = df['Acidity'].astype(float)

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   4.612442    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity  Quality
# 0    -0.491590        1
# 1    -0.722809        1
# 2     2.621636        0
# 3     0.790723        1
# 4     0.501984        1
# ...        ...      ...
# 3995  0.137784        0
# 3996  1.854235        1
# 3997 -1.334611        0
# 3998 -2.229720        1
# 3999  1.599796        1
#
# [4000 rows x 9 columns]

# %% [markdown]
# **Machine Learning**

# %%
# seperate input and Output Column
X=df.drop('Quality',axis=1)
y=df['Quality']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1234)

# %%
print(df.shape)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4000, 9)
# (3200, 8)
# (800, 8)
# (3200,)
# (800,)

# %% [markdown]
# **Decision tree**

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# **Prediction**

# %%
y_pred_dt=dtree.predict(X_test)

# %% [markdown]
# **Metrices**

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,classification_report,roc_auc_score,roc_curve

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

# %%
acc_dt=round(accuracy_score(y_test,y_pred_dt)*100,2)
f1_dt=round(f1_score(y_test,y_pred_dt),2)
precision_dt=round(precision_score(y_test,y_pred_dt),2)
recall_dt=round(recall_score(y_test,y_pred_dt),2)
print('Accuracy is:',acc_dt)
print('F1 is :',f1_dt)
print('Precision is:',precision_dt)
print('Recall is:',recall_dt)
# Out:
# Accuracy is: 82.88
# F1 is : 0.83
# Precision is: 0.83
# Recall is: 0.83

# %% [markdown]
# **Confusion Metrices**

# %%
cmt=confusion_matrix(y_test,y_pred_dt)

disp=ConfusionMatrixDisplay(confusion_matrix=cmt,display_labels=[False,True])
disp.plot()
plt.grid(True)

# %%
tn,fp,fn,tp=confusion_matrix(y_test,y_pred_dt).ravel()
print("True Negative:",tn)
print("False Positive:",fp)
print("False Negative",fn)
print("True Positive:",tp)
# Out:
# True Negative: 326
# False Positive: 70
# False Negative 67
# True Positive: 337

# %% [markdown]
# **ROC AuC Curve**

# %%
y_dt_pred_prob=dtree.predict_proba(X_test)[:,1]
fpr,tpr,threshold=roc_curve(y_test,y_dt_pred_prob)
plt.plot(fpr,tpr)
plt.show()

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
logtree=LogisticRegression()
logtree.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# **prediction**

# %%
y_pred_log=logtree.predict(X_test)

# %% [markdown]
# **Metrices**

# %%
acc_log=round(accuracy_score(y_test,y_pred_log)*100,2)
f1_log=round(f1_score(y_test,y_pred_log),2)
precision_log=round(precision_score(y_test,y_pred_log),2)
recall_log=round(recall_score(y_test,y_pred_log),2)
print('Accuracy is:',acc_log)
print('F1 is :',f1_log)
print('Precision is:',precision_log)
print('Recall is:',recall_log)
# Out:
# Accuracy is: 71.25
# F1 is : 0.71
# Precision is: 0.72
# Recall is: 0.71

# %% [markdown]
# **Confusion Metrices**

# %%
cmt=confusion_matrix(y_test,y_pred_log)
disp=ConfusionMatrixDisplay(confusion_matrix=cmt,display_labels=[False,True])
disp.plot()
plt.grid(False)
plt.show()

# %%
tn,fp,fn,tp=confusion_matrix(y_test,y_pred_log).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)
# Out:
# True negative: 284
# False postive: 112
# False negative: 118
# True postive: 286

# %% [markdown]
# **Roc Auc Curve**

# %%
y_log_pred_prob=logtree.predict_log_proba(X_test)[:,1]
fpr,tpr,threshold=roc_curve(y_test,y_log_pred_prob)
plt.plot(fpr,tpr)
plt.show()

# %% [markdown]
# **Naive bayes**

# %%
from sklearn.naive_bayes import GaussianNB
NBtree=GaussianNB()
NBtree.fit(X_train,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# **Prediction**

# %%
y_pred_NB=NBtree.predict(X_test)

# %% [markdown]
# **metrices**

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,classification_report

# %%
acc_NB=round(accuracy_score(y_test,y_pred_NB)*100,2)
f1_NB=round(f1_score(y_test,y_pred_NB),2)
precision_NB=round(precision_score(y_test,y_pred_NB),2)
recall_NB=round(recall_score(y_test,y_pred_NB),2)
print("Accuracy is",acc_NB)
print("F1 is",f1_NB)
print("Precision is:",precision_NB)
print('Recall is :',recall_NB)
# Out:
# Accuracy is 75.25
# F1 is 0.75
# Precision is: 0.76
# Recall is : 0.75

# %% [markdown]
# **Confusion Metrices**

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cmt=confusion_matrix(y_test,y_pred_NB)
disp=ConfusionMatrixDisplay(confusion_matrix=cmt,display_labels=[False,True])

disp.plot()
plt.grid(False)
plt.show()

# %%
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_NB).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)
# Out:
# True negative: 298
# False postive: 98
# False negative: 100
# True postive: 304

# %% [markdown]
# **ROC AUC Curve**

# %%
y_NB_pred_prob=NBtree.predict_proba(X_test)[:,1]   # Class-1 probabilities
fpr,tpr,threshold=roc_curve(y_test,y_NB_pred_prob) 
plt.plot(fpr,tpr)
plt.show()

# %% [markdown]
# **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
KNNtree=KNeighborsClassifier()
KNNtree.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# **Prediction**

# %%
y_pred_KNN=KNNtree.predict(X_test)

# %% [markdown]
# **Metrices**

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
acc_KNN= round(accuracy_score(y_test,y_pred_KNN)*100,2)
f1_KNN=round(f1_score(y_test,y_pred_KNN),2)
precision_KNN=round(precision_score(y_test,y_pred_KNN),2)
recall_KNN=round(recall_score(y_test,y_pred_KNN),2)
print("accuray is:",acc_KNN)
print("F1 is:",f1_KNN)
print("Precision is:",precision_KNN)
print("Recall is:",recall_KNN)
# Out:
# accuray is: 53.25
# F1 is: 0.53
# Precision is: 0.54
# Recall is: 0.51

# %% [markdown]
# **Confusion Metrices**

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cmt=confusion_matrix(y_test,y_pred_KNN)

disp=ConfusionMatrixDisplay(confusion_matrix=cmt,
                            display_labels = [False, True])
disp.plot()
plt.grid(False)
plt.show()

# %%
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_KNN).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)
# Out:
# True negative: 219
# False postive: 177
# False negative: 197
# True postive: 207

# %% [markdown]
# **ROC AUC Curve**

# %%
y_KNN_pred_prob=KNNtree.predict_proba(X_test)[:,1]   # Class-1 probabilities
fpr,tpr,threshold=roc_curve(y_test,y_KNN_pred_prob) 
plt.plot(fpr,tpr)
plt.show()

# %% [markdown]
# **RANDOM FOREST**

# %%
from sklearn.ensemble import RandomForestClassifier
RFtree=RandomForestClassifier()
RFtree.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# **Prediction**

# %%
y_pred_RF=RFtree.predict(X_test)

# %% [markdown]
# **Metrices**

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
acc_RF= round(accuracy_score(y_test,y_pred_RF)*100,2)
f1_RF=round(f1_score(y_test,y_pred_RF),2)
precision_RF=round(precision_score(y_test,y_pred_RF),2)
recall_RF=round(recall_score(y_test,y_pred_RF),2)
print("accuray is:",acc_RF)
print("F1 is:",f1_RF)
print("Precision is:",precision_RF)
print("Recall is:",recall_RF)
# Out:
# accuray is: 87.88
# F1 is: 0.88
# Precision is: 0.87
# Recall is: 0.9

# %% [markdown]
# **COnfusion Metrices**

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cmt=confusion_matrix(y_test,y_pred_RF)

disp=ConfusionMatrixDisplay(confusion_matrix=cmt,
                            display_labels = [False, True])
disp.plot()
plt.grid(False)
plt.show()

# %%
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_RF).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)
# Out:
# True negative: 340
# False postive: 56
# False negative: 41
# True postive: 363

# %% [markdown]
# **ROC AUC Curve**

# %%
y_RF_pred_prob=RFtree.predict_proba(X_test)[:,1]   # Class-1 probabilities
fpr,tpr,threshold=roc_curve(y_test,y_RF_pred_prob) 
plt.plot(fpr,tpr)
plt.show()

# %% [markdown]
# **Gradient Boosting**

# %%
from sklearn.ensemble import GradientBoostingClassifier
GB=GradientBoostingClassifier()
GB.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# **Prediction**

# %%
y_pred_GB=RFtree.predict(X_test)

# %% [markdown]
# **Metrices**

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
acc_GB= round(accuracy_score(y_test,y_pred_GB)*100,2)
f1_GB=round(f1_score(y_test,y_pred_GB),2)
precision_GB=round(precision_score(y_test,y_pred_GB),2)
recall_GB=round(recall_score(y_test,y_pred_GB),2)
print("accuray is:",acc_GB)
print("F1 is:",f1_GB)
print("Precision is:",precision_GB)
print("Recall is:",recall_GB)
# Out:
# accuray is: 87.88
# F1 is: 0.88
# Precision is: 0.87
# Recall is: 0.9

# %% [markdown]
# **Confusion Metrices**

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cmt=confusion_matrix(y_test,y_pred_GB)

disp=ConfusionMatrixDisplay(confusion_matrix=cmt,
                            display_labels = [False, True])
disp.plot()
plt.grid(False)
plt.show()

# %%
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_GB).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)
# Out:
# True negative: 340
# False postive: 56
# False negative: 41
# True postive: 363

# %% [markdown]
# **ROC AUC Curve**

# %%
y_GB_pred_prob=GB.predict_proba(X_test)[:,1]   # Class-1 probabilities
fpr,tpr,threshold=roc_curve(y_test,y_RF_pred_prob) 
plt.plot(fpr,tpr)
plt.show()

# %% [markdown]
# **Comparing Which Model Is Best**

# %%
dict1={'Accuracy':[acc_dt,acc_KNN,acc_log,acc_NB,acc_RF,acc_GB],
      "Precision":[precision_dt,precision_KNN,precision_log,precision_NB,precision_RF,precision_GB],
      "Recall":[recall_dt,recall_KNN,recall_log,recall_NB,recall_RF,recall_GB],
      "F1-score":[f1_dt,f1_KNN,f1_log,f1_NB,f1_RF,f1_GB]}

pd.DataFrame(dict1,index=['Decision Tree','K Nearest Neighbour','Logistic regression','Naive Bayes','Random Forest','Gradient Boosting'])
# Out:
#                      Accuracy  Precision  Recall  F1-score
# Decision Tree           82.88       0.83    0.83      0.83
# K Nearest Neighbour     53.25       0.54    0.51      0.53
# Logistic regression     71.25       0.72    0.71      0.71
# Naive Bayes             75.25       0.76    0.75      0.75
# Random Forest           87.88       0.87    0.90      0.88
# Gradient Boosting       87.88       0.87    0.90      0.88
